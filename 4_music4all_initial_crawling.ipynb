# %%
import pandas as pd
import time
import json

# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

# %%
data = pd.read_csv("data/MUSIC4ALL/processed/filtered_music4all_v3.csv", index_col=0)
data.head()
# Out:
#                                                lyrics  \
# 12  De tanto me perder, de andar sem sono\nPor ess...
# 16  No meio dessa confusão\nCê me deixou na mão\nC...
# 18  Radio bemba 00.0 Super Sónica\nAtento\nO bixo ...
# 19  Gostei da sua ideia\nEntrei na sua selva\nVocê...
# 47  Já tive mulheres (salve Martinho), de todos os...
#
#                         artist                           song  \
# 12         Adriana Calcanhotto                  Um Dia Desses
# 16                       Um44k                   Nossa música
# 18                   Manu Chao                           Bixo
# 19  Selvagens À Procura de Lei  Enquanto Eu Passar Na Sua Rua
# 47                      Motirô                      Senhorita
#
#                      album_name              genres              spotify_id  \
# 12                         Maré                 mpb  30Iofj66ashW2QYbROuIC2
# 16                 Nossa música             pop,rap  4hpcc2wq84pilUgDbIPkDN
# 18  Próxima Estación: Esperanza  latin,reggae,world  3JJIdDXjN8oH6ZfPv3pApB
# 19   Selvagens à Procura de Lei     indie rock,rock  0BMowyr7gejwveFKRkhj0l
# 47            Um Passo à Frente             hip hop  5se489TZrnQLUXZq8vARkY
#
#     popularity  release  danceability  energy  key  mode  valence    tempo  \
# 12        27.0     2008         0.724   0.339  0.0   1.0    0.480  119.902
# 16        62.0     2018         0.592   0.387  2.0   1.0    0.700  125.638
# 18        38.0     2001         0.658   0.452  5.0   0.0    0.971   91.321
# 19        38.0     2013         0.526   0.771  6.0   1.0    0.681  102.007
# 47        34.0     2006         0.846   0.591  1.0   0.0    0.829   94.034
#
#     duration_ms
# 12       151013
# 16       239643
# 18       112040
# 19       203987
# 47       255987

# %% [markdown]
# # Duplicated removal by artist and title

# %%
data[data.duplicated(subset=["artist", "song"])]
# Out:
# Empty DataFrame
# Columns: [lyrics, artist, song, album_name, genres, spotify_id, popularity, release, danceability, energy, key, mode, valence, tempo, duration_ms]
# Index: []

# %% [markdown]
# # Duplicated removal by spotify_id

# %%
duplicated_id_mask = data.duplicated(keep=False, subset=["spotify_id"])
duplicated = data[duplicated_id_mask]
len(duplicated)
# Out:
# 630

# %%
duplicated.to_csv("data/MUSIC4ALL/processed/duplicated_ids.csv", index=True)

# %%
unique_data = data[~duplicated_id_mask]
len(unique_data)
# Out:
# 6398

# %%
unique_data.to_csv("data/MUSIC4ALL/processed/filtered_music4all_v4_part1.csv", index=True)

# %% [markdown]
# # Crawling (Unique Data)

# %%
unique_spotify_ids = unique_data.spotify_id.tolist()

# %%
max_tracks_per_call = 50
max_feats_per_call = 100
min_wait_time_per_call = 0.3

# %%
credentials = SpotifyClientCredentials()

# %%
sp = spotipy.Spotify(auth_manager=credentials)

# %%
for start in range(0, len(unique_spotify_ids), max_tracks_per_call):
    end = start + max_tracks_per_call
    track_results = sp.tracks(unique_spotify_ids[start:end])
    
    if 'tracks' in track_results:  
        with open(f'data/MUSIC4ALL/crawled/track_results_{start}_{end-1}.json', 'w') as f:
            json.dump(track_results, f)
        print(f"Sucess")
    else:
        print(f"Error for indices {start} to {end-1}")
        
    time.sleep(min_wait_time_per_call)
# Out:
# Sucess for indices 0 to 49
# Sucess for indices 50 to 99
# Sucess for indices 100 to 149
# Sucess for indices 150 to 199
# Sucess for indices 200 to 249
# Sucess for indices 250 to 299
# Sucess for indices 300 to 349
# Sucess for indices 350 to 399
# Sucess for indices 400 to 449
# Sucess for indices 450 to 499
# Sucess for indices 500 to 549
# Sucess for indices 550 to 599
# Sucess for indices 600 to 649
# Sucess for indices 650 to 699
# Sucess for indices 700 to 749
# Sucess for indices 750 to 799
# Sucess for indices 800 to 849
# Sucess for indices 850 to 899
# Sucess for indices 900 to 949
# Sucess for indices 950 to 999
# Sucess for indices 1000 to 1049
# Sucess for indices 1050 to 1099
# Sucess for indices 1100 to 1149
# Sucess for indices 1150 to 1199
# Sucess for indices 1200 to 1249
# Sucess for indices 1250 to 1299
# Sucess for indices 1300 to 1349
# Sucess for indices 1350 to 1399
# Sucess for indices 1400 to 1449
# Sucess for indices 1450 to 1499
# Sucess for indices 1500 to 1549
# Sucess for indices 1550 to 1599
# Sucess for indices 1600 to 1649
# Sucess for indices 1650 to 1699
# Sucess for indices 1700 to 1749
# Sucess for indices 1750 to 1799
# Sucess for indices 1800 to 1849
# Sucess for indices 1850 to 1899
# Sucess for indices 1900 to 1949
# Sucess for indices 1950 to 1999
# Sucess for indices 2000 to 2049
# Sucess for indices 2050 to 2099
# Sucess for indices 2100 to 2149
# Sucess for indices 2150 to 2199
# Sucess for indices 2200 to 2249
# Sucess for indices 2250 to 2299
# Sucess for indices 2300 to 2349
# Sucess for indices 2350 to 2399
# Sucess for indices 2400 to 2449
# Sucess for indices 2450 to 2499
# Sucess for indices 2500 to 2549
# Sucess for indices 2550 to 2599
# Sucess for indices 2600 to 2649
# Sucess for indices 2650 to 2699
# Sucess for indices 2700 to 2749
# Sucess for indices 2750 to 2799
# Sucess for indices 2800 to 2849
# Sucess for indices 2850 to 2899
# Sucess for indices 2900 to 2949
# Sucess for indices 2950 to 2999
# Sucess for indices 3000 to 3049
# Sucess for indices 3050 to 3099
# Sucess for indices 3100 to 3149
# Sucess for indices 3150 to 3199
# Sucess for indices 3200 to 3249
# Sucess for indices 3250 to 3299
# Sucess for indices 3300 to 3349
# Sucess for indices 3350 to 3399
# Sucess for indices 3400 to 3449
# Sucess for indices 3450 to 3499
# Sucess for indices 3500 to 3549
# Sucess for indices 3550 to 3599
# Sucess for indices 3600 to 3649
# Sucess for indices 3650 to 3699
# Sucess for indices 3700 to 3749
# Sucess for indices 3750 to 3799
# Sucess for indices 3800 to 3849
# Sucess for indices 3850 to 3899
# Sucess for indices 3900 to 3949
# Sucess for indices 3950 to 3999
# Sucess for indices 4000 to 4049
# Sucess for indices 4050 to 4099
# Sucess for indices 4100 to 4149
# Sucess for indices 4150 to 4199
# Sucess for indices 4200 to 4249
# Sucess for indices 4250 to 4299
# Sucess for indices 4300 to 4349
# Sucess for indices 4350 to 4399
# Sucess for indices 4400 to 4449
# Sucess for indices 4450 to 4499
# Sucess for indices 4500 to 4549
# Sucess for indices 4550 to 4599
# Sucess for indices 4600 to 4649
# Sucess for indices 4650 to 4699
# Sucess for indices 4700 to 4749
# Sucess for indices 4750 to 4799
# Sucess for indices 4800 to 4849
# Sucess for indices 4850 to 4899
# Sucess for indices 4900 to 4949
# Sucess for indices 4950 to 4999
# Sucess for indices 5000 to 5049
# Sucess for indices 5050 to 5099
# Sucess for indices 5100 to 5149
# Sucess for indices 5150 to 5199
# Sucess for indices 5200 to 5249
# Sucess for indices 5250 to 5299
# Sucess for indices 5300 to 5349
# Sucess for indices 5350 to 5399
# Sucess for indices 5400 to 5449
# Sucess for indices 5450 to 5499
# Sucess for indices 5500 to 5549
# Sucess for indices 5550 to 5599
# Sucess for indices 5600 to 5649
# Sucess for indices 5650 to 5699
# Sucess for indices 5700 to 5749
# Sucess for indices 5750 to 5799
# Sucess for indices 5800 to 5849
# Sucess for indices 5850 to 5899
# Sucess for indices 5900 to 5949
# Sucess for indices 5950 to 5999
# Sucess for indices 6000 to 6049
# Sucess for indices 6050 to 6099
# Sucess for indices 6100 to 6149
# Sucess for indices 6150 to 6199
# Sucess for indices 6200 to 6249
# Sucess for indices 6250 to 6299
# Sucess for indices 6300 to 6349
# Sucess for indices 6350 to 6399

# %%
for start in range(0, len(unique_spotify_ids), max_feats_per_call):
    end = start + max_feats_per_call
    audio_feat_results = sp.audio_features(unique_spotify_ids[start:end])
    
    if len(audio_feat_results) > 0:  
        with open(f'data/MUSIC4ALL/crawled/audio_feat_results_{start}_{end-1}.json', 'w') as f:
            json.dump(audio_feat_results, f)
        print(f"Sucess")
    else:
        print(f"Error for indices {start} to {end-1}")
        
    time.sleep(min_wait_time_per_call)
# Out:
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
# Sucess
