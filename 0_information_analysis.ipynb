# %%
import pandas as pd

# %% [markdown]
# # Information

# %%
information = pd.read_csv("data/MUSIC4ALL/raw/id_information.csv", sep='\t')
information.head()
# Out:
#                  id            artist               song  \
# 0  0009fFIM1eYThaPg            Cheryl         Rain on Me
# 1  0010xmHR6UICBOYT           Oddisee     After Thoughts
# 2  002Jyd0vN4HyCpqL  Blue Öyster Cult             ME 262
# 3  006TYKNjNxWjfKjy          Rhapsody  Flames of Revenge
# 4  007LIJOPQ4Sb98qV    The Chameleons          Nostalgia
#
#                                           album_name
# 0                                            3 Words
# 1                                  The Beauty in All
# 2                                    Secret Treaties
# 3                      Legendary Years (Re-Recorded)
# 4  What Does Anything Mean? Basically (2009 Remas...

# %%
information.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109269 entries, 0 to 109268
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          109269 non-null  object
#  1   artist      109269 non-null  object
#  2   song        109269 non-null  object
#  3   album_name  109269 non-null  object
# dtypes: object(4)
# memory usage: 3.3+ MB

# %%
information.describe()
# Out:
#                       id  artist    song     album_name
# count             109269  109269  109269         109269
# unique            109269   16269   87915          38363
# top     0009fFIM1eYThaPg   Queen   Intro  Greatest Hits
# freq                   1     264      65            175

# %%
information.artist.value_counts()
# Out:
# Queen                   264
# David Bowie             226
# The Beatles             213
# Madonna                 200
# Kylie Minogue           171
#                        ...
# U.S.A. for Africa         1
# Emílio Dantas             1
# Sisqo                     1
# Noisia & The Upbeats      1
# Ace Frehley               1
# Name: artist, Length: 16269, dtype: int64

# %%
information.album_name.value_counts()
# Out:
# Greatest Hits                                            175
# UNDERTALE Soundtrack                                      53
# The Elder Scrolls V: Skyrim: Original Game Soundtrack     44
# II                                                        40
# Forever                                                   40
#                                                         ...
# Everybody in Love                                          1
# O Carnaval De Ivete Sangalo 2013 (Ao Vivo)                 1
# Desert Island                                              1
# C.W. McCall's Greatest Hits                                1
# An Anthology Of Noise And Electronic Music Vol.2           1
# Name: album_name, Length: 38363, dtype: int64

# %%
information.song.value_counts()
# Out:
# Intro                                           65
# Home                                            61
# Heaven                                          40
# Ghost                                           34
# Stay                                            34
#                                                 ..
# I'm Dancing in the Show Tonight                  1
# The Invisibility Cloak and the Library Scene     1
# Breaking Your Own Heart                          1
# The Empire Strikes First                         1
# New Rules (Initial Talk Remix)                   1
# Name: song, Length: 87915, dtype: int64
