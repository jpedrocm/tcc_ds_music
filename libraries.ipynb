# %%
# !python --version
# Out:
# Python 3.8.12

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.0.1
# ipykernel        : 6.9.0
# ipywidgets       : 7.6.5
# jupyter_client   : 7.1.2
# jupyter_core     : 4.9.1
# jupyter_server   : not installed
# jupyterlab       : not installed
# nbclient         : 0.5.11
# nbconvert        : 6.4.2
# nbformat         : 5.1.3
# notebook         : 6.4.8
# qtconsole        : 5.2.2
# traitlets        : 5.1.1

# %%
import spotipy
spotipy.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <module>
#       1 import spotipy
# ----> 2 spotipy.__version__
#
# AttributeError: module 'spotipy' has no attribute '__version__'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.3'

# %%
import seaborn
seaborn.__version__
# Out:
# '0.11.2'

# %%
import pandas
pandas.__version__
# Out:
# '1.2.3'

# %%
import spacy
spacy.__version__
# Out:
# '3.2.1'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
import numpy
numpy.__version__
# Out:
# '1.20.3'

# %%
import dython
dython.__version__
# Out:
# '0.6.7'

# %%
import tqdm
tqdm.__version__
# Out:
# '4.62.3'

# %%
import langdetect
langdetect.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <module>
#       1 import langdetect
# ----> 2 langdetect.__version__
#
# AttributeError: module 'langdetect' has no attribute '__version__'

# %%
import spacy_fastlang
spacy_fastlang.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <module>
#       1 import spacy_fastlang
# ----> 2 spacy_fastlang.__version__
#
# AttributeError: module 'spacy_fastlang' has no attribute '__version__'
