# %%
import pandas as pd

# %%
data = pd.read_csv("data/MUSIC4ALL/processed/treated_music4all_v1.csv", index_col=0)

# %%
len(data)
# Out:
# 6737

# %% [markdown]
# # Geral

# %%
market_mask = (data.markets != "UNK") & (~data.markets.str.contains("BR"))
market_filter = data[market_mask]
market_filter.head()
# Out:
#                                                  lyrics          artist  \
# 1000  Vai ser difícil, vai\nEncontrar um amor como o...             Céu
# 1719  Luz do sol\nQue a folha traga e traduz\nEm ver...  Caetano Veloso
# 1783  Eu, você, nós dois\nJá temos um passado, meu a...  Caetano Veloso
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...   Deize Tigrona
# 2274  Vejo-te em mim\ndesde o primeiro dia em que vi...             Céu
#
#                       song                                album_name  \
# 1000       Mais Um Lamento                                       CéU
# 1719            Luz do Sol                            Caetano Veloso
# 1783            Saudosismo                            Caetano Veloso
# 2039               Injecao  Bottletop Presents Sound Affects: Brazil
# 2274  A Menina E O Monstro                                    Tropix
#
#                      genres              spotify_id  popularity  danceability  \
# ...

# %%
for i, r in market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 1000 Céu | Mais Um Lamento
# 1719 Caetano Veloso | Luz do Sol
# 1783 Caetano Veloso | Saudosismo
# 2039 Deize Tigrona | Injecao
# 2274 Céu | A Menina E O Monstro
# 2443 Caetano Veloso e Gilberto Gil | Nossa Gente
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 3383 Caetano Veloso | Ingenuidade
# 4215 Ivete Sangalo | Berimbau Metalizado - Ao Vivo
# 4524 Trevor Jones | Promentory
# 5493 Tim Maia | O Caminho Do Bem
# 5538 Tom Zé | Distância
# 6180 Caetano Veloso | A Cor Amarela (The Color Yellow)
# 6431 Curumin | Magrela Fever
# 6488 Céu | Sangria
# 6489 Melody Gardot | Se Voce Me Ama
# 8223 Daniela Mercury | Viagem
# 8400 Caetano Veloso | Desde que o samba é samba - Ao vivo
# 9693 Raul Seixas | Sessão Das 10
# 9708 Karol Conká | Corre Corre Ere
# 10602 Céu | Arrastarte-Ei
# 10919 Caetano Veloso | Odeio - Ao vivo
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 11736 Caetano Veloso | Samba de Verao
# 14159 Tono | Aquele Cara
# ...

# %% [markdown]
# # Paises que falam PT

# %%
pt_market_mask = (data.markets != "UNK") & (data.markets.str.contains("PT")) & (~data.markets.str.contains("BR"))
pt_market_filter = data[pt_market_mask]
pt_market_filter.head()
# Out:
#                                                  lyrics           artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...    Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...         Tim Maia
# 5538  Meu bem a tristeza\nMe persegue\nSegue comigo\...           Tom Zé
# 8223  Suspederam a viage\nFui parar em outro trem\nQ...  Daniela Mercury
# 9708  Corre, corre, corre Erê\nCorre, corre, corre E...      Karol Conká
#
#                  song                                album_name  \
# 2039          Injecao  Bottletop Presents Sound Affects: Brazil
# 2615   Onde está você                               iCollection
# 5538        Distância                                    Tom Zé
# 8223           Viagem                           Sol Da Liberade
# 9708  Corre Corre Ere               Batuk Freak (Instrumentals)
#
#                 genres              spotify_id  popularity  danceability  \
# ...

# %%
for i, r in pt_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 5538 Tom Zé | Distância
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 17095 Carne Doce | Nova Nova
# 18100 Mariza | Rosa branca
# 18768 Claudia Leitte | Baldin de Gelo
# 19036 Maria Bethânia | O Meu Amor
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 37840 Nara Leão | João E Maria
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 46297 Daniela Mercury | Só No Balanço do Mar
# 47934 Metá Metá | Toque Certeiro
# 48218 MC Bob Rum | Rap Do Silva
# 49047 Ellen Oléria | Maria Maria
# ...

# %%
data[data.artist=="Trevor Jones"]
# Out:
#                                                  lyrics        artist  \
# 4524  INSTRUMENTAL\nRasgo minhas cicatrizes, enquant...  Trevor Jones
#
#             song                                         album_name  \
# 4524  Promentory  The Last Of The Mohicans (Original Motion Pict...
#
#                             genres              spotify_id  popularity  \
# 4524  ['soundtrack', 'soundtrack']  0l4seNH8AyE2kvjxFfpWi1          47
#
#       danceability  energy  key  ...  acousticness  instrumentalness  \
# 4524         0.183   0.235    2  ...      0.000117             0.857
#
#       liveness  loudness  speechiness  time_signature  explicit  markets  \
# 4524     0.136   -17.632       0.0366               4         0    CA,US
#
#       nb_genres  year
# 4524          2  1992
#
# [1 rows x 24 columns]

# %%
data = data.drop(labels=4524)

# %%
data[data.artist=="Stan Getz"]
# Out:
#                                                   lyrics     artist  \
# 30743  Quiet nights of quiet stars\nQuiet chords from...  Stan Getz
# 56379  Haja o que houver,\nHá sempre um homem, para u...  Stan Getz
# 56400  Vivo sonhando, sonhando mil horas sem fim\nTem...  Stan Getz
# 57386  Doralice eu bem que te disse\nAmar é tolice, é...  Stan Getz
# 68550  Só danço samba\nSó danço samba\nVai, vai, vai,...  Stan Getz
# 73200  Espere um pouco meu amor\nDeixa outro amor che...  Stan Getz
# 96018  Tá fazendo um ano e meio, amor\nQue o nosso la...  Stan Getz
#
#                                           song  \
# 30743  Corcovado (Quiet Nights Of Quiet Stars)
# 56379                            O Grande Amor
# 56400                            Vivo Sonhando
# 57386                                 Doralice
# 68550                           Só Danço Samba
# 73200                     Saudade Vem Correndo
# 96018               Para Machuchar Meu Coracao
#
# ...

# %%
data[data.artist=="Stan Getz"].iloc[0].lyrics
# Out:
# 'Quiet nights of quiet stars\nQuiet chords from my guitar\nFloating on the silence that surrounds us\nQuiet thoughts and quiet dreams\nQuiet walks by quiet streams\nAnd a window that looks out on Corcovado\nOh, how lovely\n\nUm cantinho, um violão\nEsse amor, uma canção\nPra fazer feliz a quem se ama\nMuita calma pra pensar\nE ter tempo pra sonhar\nDa janela vê-se o Corcovado\nO Redentor que lindo\nQuero a vida sempre assim\nCom você perto de mim\nAté o apagar da velha chama\nE eu, que era triste\nDescrente desse mundo\nAo encontrar você eu conheci\nO que é a felicidade, meu amor\n\nQuero a vida sempre assim\nCom você perto de mim\nAté o apagar da velha chama\nE eu, que era triste\nDescrente desse mundo\nAo encontrar você eu conheci\nO que é a felicidade, meu amor'

# %%
data[data.artist=="Baden Powell"]
# Out:
#                                                   lyrics        artist  \
# 2771   O homem que diz "dou" não dá\nPorque quem dá m...  Baden Powell
# 51378  Iemanjá, Iemanjá\nIemanjá é dona Janaína que v...  Baden Powell
# 61564  Labareda te encostou\nLá vai, lá vai labareda\...  Baden Powell
# 62116  Olha que coisa mais linda\nMais cheia de graça...  Baden Powell
# 96088  Quem é homem de bem não trai\nO amor que lhe q...  Baden Powell
#
#                            song                                album_name  \
# 2771           Canto De Ossanha                        Tristeza on Guitar
# 51378          Canto de Iemanja  Os Afro Samba (feat. Vinicius de Moraes)
# 61564                  Labareda                            Os Afro-Sambas
# 62116         Garota De Ipanema                 Pure Brazil II - Feijoada
# 96088  Variações Sobre Berimbau                            Os Afro-Sambas
#
#                        genres              spotify_id  popularity  \
# ...

# %%
pt_artists = ["Carminho", "Moonspell", "Mariza"]

# %%
pt_labels = data[data.artist.isin(pt_artists)].index

# %%
data = data.drop(labels=pt_labels)

# %%
len(data)
# Out:
# 6724

# %%
ao_market_mask = (data.markets != "UNK") & (data.markets.str.contains("AO")) & (~data.markets.str.contains("BR"))
ao_market_filter = data[ao_market_mask]
ao_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in ao_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 19036 Maria Bethânia | O Meu Amor
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 37840 Nara Leão | João E Maria
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# ...

# %%
mz_market_mask = (data.markets != "UNK") & (data.markets.str.contains("MZ")) & (~data.markets.str.contains("BR"))
mz_market_filter = data[mz_market_mask]
mz_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in mz_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 19036 Maria Bethânia | O Meu Amor
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 37840 Nara Leão | João E Maria
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 47934 Metá Metá | Toque Certeiro
# 48218 MC Bob Rum | Rap Do Silva
# 49047 Ellen Oléria | Maria Maria
# 51335 Toque no Altar | Restitui
# ...

# %%
gw_market_mask = (data.markets != "UNK") & (data.markets.str.contains("GW")) & (~data.markets.str.contains("BR"))
gw_market_filter = data[gw_market_mask]
gw_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in gw_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 46297 Daniela Mercury | Só No Balanço do Mar
# 47934 Metá Metá | Toque Certeiro
# ...

# %%
mo_market_mask = (data.markets != "UNK") & (data.markets.str.contains("MO")) & (~data.markets.str.contains("BR"))
mo_market_filter = data[mo_market_mask]
mo_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in mo_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 46297 Daniela Mercury | Só No Balanço do Mar
# 47934 Metá Metá | Toque Certeiro
# ...

# %%
cv_market_mask = (data.markets != "UNK") & (data.markets.str.contains("CV")) & (~data.markets.str.contains("BR"))
cv_market_filter = data[cv_market_mask]
cv_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in cv_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 46297 Daniela Mercury | Só No Balanço do Mar
# 47934 Metá Metá | Toque Certeiro
# ...

# %%
st_market_mask = (data.markets != "UNK") & (data.markets.str.contains("ST")) & (~data.markets.str.contains("BR"))
st_market_filter = data[st_market_mask]
st_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in st_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 40108 Pabllo Vittar | K.O.
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 47934 Metá Metá | Toque Certeiro
# 48218 MC Bob Rum | Rap Do Silva
# 49047 Ellen Oléria | Maria Maria
# 51335 Toque no Altar | Restitui
# 53995 Curumin | Caixa Preta (feat. Bnegão & Lucas Santtana)
# 54055 Ellen Oléria | Zumbi
# 54343 Maysa | Bronzes E Cristais
# ...

# %%
tl_market_mask = (data.markets != "UNK") & (data.markets.str.contains("TL")) & (~data.markets.str.contains("BR"))
tl_market_filter = data[tl_market_mask]
tl_market_filter.head()
# Out:
#                                                  lyrics         artist  \
# 2039  Ai!\nAi!\n\nQuando eu vô ao médico,\nSinto uma...  Deize Tigrona
# 2615  Não, eu não mudei\nSó despertei pra certas coi...       Tim Maia
# 2988  Eu fiz um par de brincos\nPra brincar todo dia...        Curumin
# 5493  O caminho do bem\nO caminho do bem\nO caminho ...       Tim Maia
# 6431  Eu me coço e saio fora.\nPensamento tá dorment...        Curumin
#
#                   song                                         album_name  \
# 2039           Injecao           Bottletop Presents Sound Affects: Brazil
# 2615    Onde está você                                        iCollection
# 2988   Mistério Stereo                                       JapanPopShow
# 5493  O Caminho Do Bem  World Psychedelic Classics 4: Nobody Can Live ...
# 6431     Magrela Fever                                       JapanPopShow
#
#                        genres              spotify_id  popularity  \
# ...

# %%
for i, r in tl_market_filter.iterrows():
    print(i, r.artist, "|", r.song)
# Out:
# 2039 Deize Tigrona | Injecao
# 2615 Tim Maia | Onde está você
# 2988 Curumin | Mistério Stereo
# 5493 Tim Maia | O Caminho Do Bem
# 6431 Curumin | Magrela Fever
# 8223 Daniela Mercury | Viagem
# 9708 Karol Conká | Corre Corre Ere
# 11201 Pabllo Vittar | Nêga
# 11380 Chico Buarque | Calice
# 14159 Tono | Aquele Cara
# 14565 Daniela Mercury | Sol da Liberdade (feat. Milton Nascimento)
# 14743 Barbatuques | Você Chegou
# 15862 Céu | Retrovisor
# 17095 Carne Doce | Nova Nova
# 18768 Claudia Leitte | Baldin de Gelo
# 20326 Daniela Mercury | Musa Calabar
# 23635 Wanessa Camargo | LOKO!
# 23709 Chico Buarque | Caçada
# 24135 Maysa | As Praias Desertas
# 25011 Seu Jorge | Carolina
# 28635 Luisa Maita | Alento
# 37736 Metá Metá | Imagem do Amor
# 40108 Pabllo Vittar | K.O.
# 42036 Daniela Mercury | Nobre Vagabundo
# 43262 Maysa | Eu Não Existo Sem Você
# 44680 Metá Metá | Três Amigos
# 46297 Daniela Mercury | Só No Balanço do Mar
# 47934 Metá Metá | Toque Certeiro
# ...

# %%
data_clone = data.copy()

# %%
data_clone["markets_str"] = data_clone.markets.apply(lambda l: ','.join(l))

# %% [markdown]
# # Generos Portugueses

# %%
genres = ["fado", "tuba", "kuduro", "cante", "pimba"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# fado 0
# tuba 0
# kuduro 0
# cante 0
# pimba 0

# %% [markdown]
# # Generos Angolanos

# %%
genres = ["rebita", "kilapanda", "kuduro", "semba", "merengue", "kazukuta", "adoco"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# rebita 0
# kilapanda 0
# kuduro 0
# semba 0
# merengue 0
# kazukuta 0
# adoco 0

# %% [markdown]
# # Generos Mocambicanos

# %%
genres = ["marrabenta", "xingombela", "magika", "zukuta", "pandza"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# marrabenta 0
# xingombela 0
# magika 0
# zukuta 0
# pandza 0

# %% [markdown]
# # Generos Caboverdianos

# %%
genres = ["coladeira", "morna", "tabanca", "cola", "funana", "zouk", "cumbia", "rumba", "batuque"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# coladeira 0
# morna 0
# tabanca 0
# cola 0
# funana 0
# zouk 0
# cumbia 0
# rumba 0
# batuque 0

# %% [markdown]
# # Generos Guineenses

# %%
genres = ["soukou", "makossa"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# soukou 0
# makossa 0

# %% [markdown]
# # Generos Sao tomeenses

# %%
genres = ["dexa", "socope", "ussua"]

for g in genres:
    print(g, len(data_clone[data_clone.markets_str.str.contains(g)]))
# Out:
# dexa 0
# socope 0
# ussua 0

# %%
data.to_csv("data/MUSIC4ALL/processed/treated_music4all_v2.csv", index=True)
